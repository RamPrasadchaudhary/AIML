# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('Bengaluru_House_Data.csv')

# %%
df.columns
# Out:
# Index(['area_type', 'availability', 'location', 'size', 'society',
#        'total_sqft', 'bath', 'balcony', 'price'],
#       dtype='object')

# %%
sns.countplot(x='area_type',data=df)
# Out:
# <Axes: xlabel='area_type', ylabel='count'>

# %%
sns.countplot(x='availability',data=df)
# Out:
# <Axes: xlabel='availability', ylabel='count'>

# %%
df.isna().sum()
# Out:
# area_type          0
# availability       0
# location           1
# size              16
# society         5502
# total_sqft         0
# bath              73
# balcony          609
# price              0
# dtype: int64

# %%
df['location'].unique()
# Out:
# array(['Electronic City Phase II', 'Chikka Tirupathi', 'Uttarahalli', ...,
#        '12th cross srinivas nagar banshankari 3rd stage',
#        'Havanur extension', 'Abshot Layout'], shape=(1306,), dtype=object)

# %%
from enum import auto
df['location'].value_counts().plot(kind='pie',autopct='%.2f')
# Out:
# <Axes: ylabel='count'>

# %%
from pathlib import WindowsPath
import matplotlib.pyplot as plt
plt.pie(df['location'].value_counts(),labels=df['location'].unique(),autopct='%.2f',wedgeprops=dict(width=0.4))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[20], line 3
#       1 from pathlib import WindowsPath
#       2 import matplotlib.pyplot as plt
# ----> 3 plt.pie(df['location'].value_counts(),labels=df['location'].unique(),autopct='%.2f',wedgeprops=dict(width=0.4))
#
# File c:\Users\91932\AppData\Local\Programs\Python\Python313\Lib\site-packages\matplotlib\_api\deprecation.py:453, in make_keyword_only.<locals>.wrapper(*args, **kwargs)
#     447 if len(args) > name_idx:
#     448     warn_deprecated(
#     449         since, message="Passing the %(name)s %(obj_type)s "
#     450         "positionally is deprecated since Matplotlib %(since)s; the "
#     451         "parameter will become keyword-only in %(removal)s.",
#     452         name=name, obj_type=f"parameter of {func.__name__}()")
# --> 453 return func(*args, **kwargs)
#
# ...

# %%
plt.hist(df['price'],bins=10)
# Out:
# (array([1.93661e+05, 1.64290e+04, 6.99100e+03, 2.35870e+04, 4.26690e+04,
#         1.26380e+04, 3.39200e+03, 6.56000e+02, 1.15000e+02, 1.50000e+01]),
#  array([  1105. ,  13301.6,  25498.2,  37694.8,  49891.4,  62088. ,
#          74284.6,  86481.2,  98677.8, 110874.4, 123071. ]),
#  <BarContainer object of 10 artists>)

# %%
sns.distplot(df['duration'])
# Out:
# <ipython-input-18-30626c77febe>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['duration'])
# <Axes: xlabel='duration', ylabel='Density'>

# %%
plt.figure(figsize=(8, 6))
sns.histplot(df['price'], kde=True, color='purple', edgecolor='black')
plt.title('Distribution Plot of Price')
plt.xlabel('Price')
plt.ylabel('Density')
plt.show()

# %%
if 'Unnamed: 0' in df.columns:
    df.rename(columns={'Unnamed: 0': 'id'}, inplace=True)
